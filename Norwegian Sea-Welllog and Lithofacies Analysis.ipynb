# %% [markdown]
# # Norwegian Sea: Well-log and Lithofacies Analysis Using Data

# %% [markdown]
# ![Norwegian%20image.png](attachment:Norwegian%20image.png)

# %% [markdown]
# ## Table of Contents
#
# <li><a href="#Intro">Introduction<a></li>
# <li><a href="##Research">Research Questions<a></li>
# <li><a href="#data">Data Wrangling<a></li>
# <li><a href="#Explore">Exploratory Data Analysis<a></li>
# <li><a href="#Discuss">Discussion<a></li>
# <li><a href="#Conclusion">Conclusion<a></li>

# %% [markdown]
# <a id='Intro'></a>
# ## Introduction

# %% [markdown]
# <a id='data'></a>
# ## Data Wrangling

# %% [markdown]
# <a id="Explore"></a>
# ## Exploratory Data Analysis

# %% [markdown]
# <a id="discuss"></a>
# ## Discussion

# %% [markdown]
# <a id="#Conclusion"></a>
# ## Conclusion
